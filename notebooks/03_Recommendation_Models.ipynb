# %% [markdown]
# # Steps 5, 6, 7, 8: Recommendation Engines Sandbox
# Test the outputs of our Market Basket and Collaborative Filtering engines.

# %%
import sys
sys.path.append('..')
from src.recommendation import recommend_products, recommend_similar_products, recommend_for_user

# %% [markdown]
# ## 1. Product Recommendations (Market Basket Analysis)
# Recommend items frequently bought together based on Association Rules.

# %%
target_product = "Organic Hass Avocado"
print(f"Top products frequently bought with '{target_product}':")
print(recommend_products(target_product, top_n=5))
# Out:
# Top products frequently bought with 'Organic Hass Avocado':
# ['Bag of Organic Bananas', 'Organic Baby Spinach', 'Organic Strawberries']

# %% [markdown]
# ## 2. Similar Products (Item-Based)
# Recommend products from the same aisle to help customers discover variations.

# %%
target_product = "Organic Hass Avocado"
print(f"Products similar to '{target_product}':")
print(recommend_similar_products(target_product, top_n=5))
# Out:
# Products similar to 'Organic Hass Avocado':
# ['European Cucumber', 'Local Living Butter Lettuce', 'Gold Potatoes', 'Juicing Carrots', 'Organic Yukon Gold Potato Bag']

# %% [markdown]
# ## 3. User Recommendations (User-Based)
# Analyze a user's past purchases and recommend what they should buy next.

# %%
user_id = 1
print(f"Personalized recommendations for User ID {user_id}:")
print(recommend_for_user(user_id, top_n=5))
# Out:
# Personalized recommendations for User ID 1:
# ['Uncured Cracked Pepper Beef', 'Healthy Pop Butter Popcorn', 'Jasmine Tea Unfiltered Ginger Ale', 'Sparkling Blush Grape Juice', 'Dried Sweetened Cranberries']
